# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
filt = (df['Country'] == 'Viet Nam')
vietnam_df = df.loc[filt]

# %%
vietnam_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 161                 I am a developer by profession      Yes
# 1100                I am a developer by profession      Yes
# 1262                I am a developer by profession      Yes
# 2452        I am a student who is learning to code       No
# 2857        I am a student who is learning to code      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 161                                Once a month or more often
# 1100        Less than once a month but more than once per ...
# 1262                                                    Never
# 2452                                                    Never
# 2857                                                    Never
#
#                                                    OpenSource  \
# Respondent
# 161         OSS is, on average, of HIGHER quality than pro...
# 1100        The quality of OSS and closed source software ...
# 1262        The quality of OSS and closed source software ...
# 2452        OSS is, on average, of HIGHER quality than pro...
# 2857        OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment   Country         Student  \
# Respondent
# 161                         Employed part-time  Viet Nam              No
# 1100                        Employed full-time  Viet Nam              No
# 1262        Not employed, but looking for work  Viet Nam              No
# 2452                        Employed full-time  Viet Nam  Yes, full-time
# 2857                        Employed part-time  Viet Nam  Yes, full-time
#
#                                                       EdLevel  \
# Respondent
# 161                  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1100                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1262                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2452        Some college/university study without earning ...
# 2857        Secondary school (e.g. American high school, G...
#
#                                                UndergradMajor  \
# Respondent
# 161                             Web development or web design
# 1100        Information systems, information technology, o...
# 1262        Computer science, computer engineering, or sof...
# 2452                            Web development or web design
# 2857                                                      NaN
#
#                                                      EduOther  \
# Respondent
# 161         Taken an online course in programming or softw...
# 1100        Taken an online course in programming or softw...
# 1262        Taken an online course in programming or softw...
# 2452        Taken an online course in programming or softw...
# 2857        Taken an online course in programming or softw...
#
#                        OrgSize  \
# Respondent
# 161         10 to 19 employees
# 1100                       NaN
# 1262                       NaN
# 2452                       NaN
# 2857                       NaN
#
#                                                       DevType YearsCode  \
# Respondent
# 161         Developer, back-end;Developer, front-end;Devel...        11
# 1100        Developer, back-end;Developer, front-end;Devel...        15
# 1262                                                      NaN         5
# 2452                            Developer, full-stack;Student         3
# 2857                              Developer, back-end;Student         6
#
#                       Age1stCode YearsCodePro              CareerSat  \
# Respondent
# 161                           22           10         Very satisfied
# 1100                          14            8  Slightly dissatisfied
# 1262                          16            3      Very dissatisfied
# 2452                          18          NaN                    NaN
# 2857        Younger than 5 years          NaN                    NaN
#
#                         JobSat        MgrIdiot MgrMoney   MgrWant  \
# Respondent
# 161         Slightly satisfied             NaN      NaN       NaN
# 1100            Very satisfied  Very confident       No  Not sure
# 1262                       NaN             NaN      NaN       NaN
# 2452                       NaN             NaN      NaN       NaN
# 2857                       NaN             NaN      NaN       NaN
#
#                                                       JobSeek  \
# Respondent
# 161                           I am actively looking for a job
# 1100        I’m not actively looking, but I am open to new...
# 1262                          I am actively looking for a job
# 2452                          I am actively looking for a job
# 2857             I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 161                1-2 years ago
# 1100        Less than a year ago
# 1262               1-2 years ago
# 2452        Less than a year ago
# 2857        Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 161         Write code by hand (e.g., on a whiteboard);Com...       No
# 1100        Interview with people in senior / management r...       No
# 1262        Interview with people in senior / management r...       No
# 2452                                                      NaN      NaN
# 2857                                                      NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 161         Financial performance or funding status of the...
# 1100        Languages, frameworks, and other technologies ...
# 1262        Industry that I'd be working in;Languages, fra...
# 2452        Specific department or team I'd be working on;...
# 2857        Specific department or team I'd be working on;...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 161                          I was preparing for a job search            VND
# 1100         My job status changed (promotion, new job, etc.)            VND
# 1262                         I was preparing for a job search            NaN
# 2452                         I was preparing for a job search            NaN
# 2857        Something else changed (education, award, medi...            NaN
#
#                CurrencyDesc   CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 161         Vietnamese dong  85000000.0  Monthly        43956.0         48.0
# 1100        Vietnamese dong         NaN  Monthly            NaN          NaN
# 1262                    NaN         NaN      NaN            NaN          NaN
# 2452                    NaN         NaN      NaN            NaN          NaN
# 2857                    NaN         NaN      NaN            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 161         There is a schedule and/or spec (made by me or...
# 1100        There's no schedule or spec; I work on what se...
# 1262                                                      NaN
# 2452                                                      NaN
# 2857                                                      NaN
#
#                                                 WorkChallenge  \
# Respondent
# 161         Meetings;Time spent commuting;Toxic work envir...
# 1100        Lack of support from management;Time spent com...
# 1262                                                      NaN
# 2452                                                      NaN
# 2857                                                      NaN
#
#                                                    WorkRemote  \
# Respondent
# 161                                     A few days each month
# 1100        Less than half the time, but at least one day ...
# 1262                                                      NaN
# 2452                                                      NaN
# 2857                                                      NaN
#
#                                                    WorkLoc  \
# Respondent
# 161                                                   Home
# 1100        Other place, such as a coworking space or cafe
# 1262                                                   NaN
# 2452                                                   NaN
# 2857                                                   NaN
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 161              Far above average  Yes, because I see value in code review
# 1100        A little above average  Yes, because I see value in code review
# 1262        A little below average                                      NaN
# 2452                           NaN                                      NaN
# 2857                           NaN                                      NaN
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 161                7.0                          No, but I think we should
# 1100              50.0  Yes, it's not part of our process but the deve...
# 1262               NaN                                                NaN
# 2452               NaN                                                NaN
# 2857               NaN                                                NaN
#
#            PurchaseHow                      PurchaseWhat  \
# Respondent
# 161           Not sure  I have a great deal of influence
# 1100          Not sure             I have some influence
# 1262               NaN                               NaN
# 2452               NaN                               NaN
# 2857               NaN                               NaN
#
#                         LanguageWorkedWith  \
# Respondent
# 161                HTML/CSS;JavaScript;PHP
# 1100        HTML/CSS;JavaScript;TypeScript
# 1262           Bash/Shell/PowerShell;C;C++
# 2452               HTML/CSS;JavaScript;PHP
# 2857                          Go;Other(s):
#
#                          LanguageDesireNextYear  \
# Respondent
# 161                  Go;HTML/CSS;JavaScript;PHP
# 1100                                         Go
# 1262         Bash/Shell/PowerShell;C;C++;Python
# 2452        HTML/CSS;JavaScript;PHP;Python;Ruby
# 2857                                     C++;Go
#
#                              DatabaseWorkedWith  \
# Respondent
# 161           Elasticsearch;MariaDB;MySQL;Redis
# 1100        DynamoDB;MongoDB;MySQL;Redis;SQLite
# 1262                                        NaN
# 2452                                      MySQL
# 2857                                 PostgreSQL
#
#                        DatabaseDesireNextYear         PlatformWorkedWith  \
# Respondent
# 161         Elasticsearch;MariaDB;MySQL;Redis  AWS;Linux;MacOS;WordPress
# 1100                      Firebase;PostgreSQL     AWS;Docker;Linux;MacOS
# 1262                               PostgreSQL                      Linux
# 2452                                    MySQL                        NaN
# 2857                       MongoDB;PostgreSQL         Docker;Linux;Slack
#
#                              PlatformDesireNextYear       WebFrameWorkedWith  \
# Respondent
# 161         AWS;Docker;Kubernetes;Linux;MacOS;Slack           jQuery;Laravel
# 1100                              Docker;Kubernetes  Express;jQuery;React.js
# 1262                                          Linux                      NaN
# 2452                                            NaN           jQuery;Laravel
# 2857                       Docker;Linux;MacOS;Slack                Other(s):
#
#            WebFrameDesireNextYear MiscTechWorkedWith MiscTechDesireNextYear  \
# Respondent
# 161                jQuery;Laravel                NaN                    NaN
# 1100             Express;React.js            Node.js                Node.js
# 1262                       Django                NaN                    NaN
# 2452                Ruby on Rails                NaN                    NaN
# 2857                    Other(s):                NaN                    NaN
#
#                                           DevEnviron        OpSys  \
# Respondent
# 161         NetBeans;Notepad++;PHPStorm;Sublime Text        MacOS
# 1100                                            Atom        MacOS
# 1262                                             NaN  Linux-based
# 2452                           PHPStorm;Sublime Text      Windows
# 2857                              Visual Studio Code  Linux-based
#
#                                                    Containers  \
# Respondent
# 161                            Development;Testing;Production
# 1100                                   Development;Production
# 1262                                  I do not use containers
# 2452                                  I do not use containers
# 2857        Development;Testing;Production;Outside of work...
#
#                                                 BlockchainOrg  \
# Respondent
# 161         Accepting Bitcoin or other coins and tokens as...
# 1100                  Non-currency applications of blockchain
# 1262                                                      NaN
# 2452                                                      NaN
# 2857                                                      NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 161                                                       NaN         No
# 1100        Useful across many domains and could change ma...        Yes
# 1262                                                      NaN         No
# 2452                                                      NaN        Yes
# 2857        Useful for immutable record keeping outside of...        Yes
#
#             ITperson  OffOn               SocialMedia  \
# Respondent
# 161         Also Yes     No                   YouTube
# 1100             Yes    Yes                       NaN
# 1262             NaN  What?  I don't use social media
# 2452             Yes    Yes                  Facebook
# 2857        Also Yes    Yes                   Twitter
#
#                         Extraversion   ScreenName SOVisit1st  \
# Respondent
# 161                           Online  Screen Name       2015
# 1100                          Online     Username       2012
# 1262        In real life (in person)     Username       2013
# 2452                          Online       UserID       2018
# 2857                         Neither       UserID       2015
#
#                       SOVisitFreq  \
# Respondent
# 161         Daily or almost daily
# 1100        Daily or almost daily
# 1262        Daily or almost daily
# 2452        Daily or almost daily
# 2857                          NaN
#
#                                                     SOVisitTo  \
# Respondent
# 161                        Find answers to specific questions
# 1100        Find answers to specific questions;Learn how t...
# 1262        Find answers to specific questions;Get a sense...
# 2452        Find answers to specific questions;Learn how t...
# 2857        Find answers to specific questions;Learn how t...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 161                 6-10 times per week            They were about the same
# 1100                 3-5 times per week  Stack Overflow was slightly faster
# 1262                 3-5 times per week            They were about the same
# 2452                 3-5 times per week  Stack Overflow was slightly faster
# 2857        More than 10 times per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 161                   NaN       Yes
# 1100        11-30 minutes       Yes
# 1262                  NaN       Yes
# 2452         0-10 minutes       Yes
# 2857        11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 161                                     Daily or almost daily
# 1100                      Less than once per month or monthly
# 1262        I have never participated in Q&A on Stack Over...
# 2452        I have never participated in Q&A on Stack Over...
# 2857                          A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 161         No, I knew that Stack Overflow had a job board...
# 1100                                                      Yes
# 1262                                                      Yes
# 2452        No, I didn't know that Stack Overflow had a jo...
# 2857                                                      Yes
#
#                                        EntTeams           SOComm  \
# Respondent
# 161         No, and I don't know what those are  Yes, definitely
# 1100        No, and I don't know what those are  Yes, definitely
# 1262        No, and I don't know what those are   No, not really
# 2452        No, and I don't know what those are   No, not really
# 2857        No, and I don't know what those are  Yes, definitely
#
#                                        WelcomeChange  \
# Respondent
# 161            A lot more welcome now than last year
# 1100        Somewhat more welcome now than last year
# 1262           A lot less welcome now than last year
# 2452         Just as welcome now as I felt last year
# 2857         Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 161         Tech articles written by other developers;Indu...  35.0    Man
# 1100        Tech articles written by other developers;Cour...   NaN    Man
# 1262        Tech articles written by other developers;Indu...  29.0    Man
# 2452        Tech articles written by other developers;Indu...  22.0  Woman
# 2857                Tech articles written by other developers   NaN    NaN
#
#            Trans                Sexuality   Ethnicity Dependents  \
# Respondent
# 161           No                      NaN         NaN        Yes
# 1100          No  Straight / Heterosexual  East Asian        Yes
# 1262          No                      NaN         NaN        NaN
# 2452          No                      NaN         NaN         No
# 2857         NaN                      NaN         NaN        NaN
#
#                      SurveyLength                  SurveyEase
# Respondent
# 161                      Too long                        Easy
# 1100                     Too long  Neither easy nor difficult
# 1262        Appropriate in length  Neither easy nor difficult
# 2452                     Too long  Neither easy nor difficult
# 2857                          NaN                         NaN

# %%
vietnam_df.to_csv('data/vietnam.csv')

# %%
vietnam_df.to_json('data/vietnam.json', orient='records', lines=True)
